# %% [markdown]
# # MP3 - Aufgabenblatt 1: Einen Ton mathematisch modellieren
# ## Einleitung
#
# Jedes Instrument und auch die menschliche Stimme verursachteinegewisseArtvonSchwingung,auchwenndiese für normale Menschen nicht wahrnehmbar ist und nur mit Hilfe eines Computers oder eines Oszilloskops sichtbar gemacht werden kann. So ist beispielsweise der Ton einer Stimmgabel mathematisch bzw. physikalisch nichts anderes als eine harmonische Schwingung in Form einer Sinuskurve und kann mit der Sinusfunktion
#
# $$g(t) = A \cdot sin(2 \cdot π \cdot f \cdot  t)$$
#
# modelliert werden. Hier seht ihr den (Teil-)Graphen einer Sinusschwingung:
# ![Stimmgabel.png](attachment:Stimmgabel.png)
#
# Dabei steht
#
# - $t$ für die **Zeit**.
# - $A$ für die **Amplitude** und gibt die maximale **Lautstärke** des Tons an. Das heißt je höher die Amplitude, desto lauter wird der Ton wahrgenommen.
# - $f$ für die **Frequenz** und gibt die **Tonhöhe** an. der Ab stand zwischen zwei gleichen Maxima wird als Periode $T = 1/f$ bezeichnet. D.h. je größer die Frequenz $f$ ist, desto näher liegen die Maxima nebeneinander und umso höher wird der Ton wahrgenommen. Die Frequenz wird in Hertz [Hz] angegeben.

# %% [markdown]
# ## Aufgabenbeschreibung
#
# Euer Ziel wird es sein, in die Rolle des Computers zu schlüpfen und Töne selber mathematisch zu modellieren. Ein Ton der Form $$g1(t) = sin(200·2π ·t)$$ findet ihr in **Aufgabe 1**. Die Abspieldauer des Tons ist so programmiert, dass sie 6s beträgt.

# %% [markdown]
# *Damit dieses Arbeitsblatt funktioniert, musst du als erstes den folgenden Code ausführen. Klicke dazu auf das Code Feld und drücke auf "Run" (oder drücke Shift + Enter).*

# %%
# Hier nichts ändern
include("./code/MP3Tests.jl")
# Out:
# WARNING: replacing module MP3.
# Main.MP3

# %% [markdown]
# ## Aufgabe 1 *a)*
# Hört und schaut euch zunächst den Sinuston an, indem ihr in das nachfolgende Code Feld klickt und dann "Run" (oder *Shift + Enter") drückt.

# %%
# Ab hier nichts mehr ändern
MP3.AB1A1aPlay()
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1A1a.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# Welchen Wert hat die Amplitude des Tons?
# *(Ersetze NaN durch den Wert.)*

# %%
amplitude = 1
# Ab hier nichts mehr ändern
MP3.AB1Aufgabe1a(amplitude)
# Out:
# Richtig

# %% [markdown]
# ## Aufgabe 1 *b)*
# Je größer die Amplitude gewählt wird, desto lauter wird der Ton wahrgenommen. Überlegt euch, wie ihr die Konstante `amplitude` beim Ton wählen müsst, damit der Ton lauter bzw. leiser klingt. Tragt dazu dazu anstelle von `NaN`verschiedene Werte für `amplitude` ein und überprüft jeweils mit *"Run"* (oder *Shift + Enter*) euer Ergebnis. Euch wird anschließend die Schwingung des Ausgangston $g(t) = sin(200·2·π·t)$ und die des neuen Tons im Intervall [0,0.1] graphisch angezeigt.

# %%
amplitude = 3
# Ab hier nichts mehr ändern
MP3.AB1A1bPlay(amplitude)
MP3.AB1Aufgabe1b(amplitude)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1A1b.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ## Aufgabe 1 *c)*
# Bisher war die Amplitude des Tons über die Zeit konstant. Nun wollen wir die Lautstärke des Tons über die Zeit ändern.
#
# Überlege dir, wie die Amplitude $A$ in Abhängigkeit der Zeit $t$ gewählt werden musst, damit die Lautstärke zum Zeitpunkt $t=0$ den Wert Null hat und lineares Wachstum in $t$ besitzt. Du kennst bereits viele Funktionen mit linearem Wachstum, nämlich alle ansteigenden Geraden.
#
# *Ersetze im folgenden Code `NaN` durch einen Ausdruck in $t$, der lineares Wachstum in $t$ beschreibt und zum Zeitpunkt $t = 0$ den Wert Null hat. Klicke anschließend auf den "Run" Button, um dir deinen erzeugten Ton anzuhören und anzusehen. Falls deine Eingabe fehlerhaft ist, bekommst du eine Warnung angezeigt. Korrigiere deine Eingabe in diesem Fall.*
#
# **Hinweis: Falls du beim Lösen dieser Aufgabe Hilfe benötigst, siehe dir [Hilfekarte 1](./MP3Hilfekarte1.ipynb) an**

# %%
A(t) = t; # Ersetze 'NaN' durch einen Ausdruck in t, der lineares Wachstum in t beschreibt und bei t=0 den Wert Null hat

# Ab hier nichts mehr ändern
MP3.AB1A1c1Play(A)
MP3.AB1Aufgabe1c1(A)
# Out:
# UndefVarError: AB1A1c1Play not defined
#
# Stacktrace:
#  [1] getproperty(::Module, ::Symbol) at .\sysimg.jl:13
#  [2] top-level scope at In[67]:2

# %% [markdown]
# # Aufgabe 1 *d)*
#
# Nun wollen wir einen Ton erzeugen, dessen Amplitude linear fällt und dessen Länge 6 s beträgt. Überlege dir dazu, wie die Amplitude eines Tons in Abhängigkeit von $t$ gewählt werden muss, damit diese linear fällt und bei $t = 6$ den Wert $0$ hat.
#
# *Ersetze im folgenden Code `NaN` durch einen Term, der die Amplitude eines Tons beschreibt, dessen Amplitude linear fällt und der 6 s lang ist. Das heißt, dessen Amplitude zum Zeitpunkt $t = 6$ den Wert Null hat. Klicke auf "Run", um den Ton anzusehen und anzuhören. Falls deine Eingabe fehlerhaft ist, bekommst du eine Warnung. Korrigiere dich in diesem Fall.*
#
# **Hinweis: Falls du beim Lösen dieser Aufgabe Hilfe benötigst, siehe dir [Hilfekarte 1](./MP3Hilfekarte1.ipynb) an**

# %%
A(t) = 6-t; # Ersetze 'NaN' durch einen Term in t, der die Amplitude eines Tons beschreibt, der 0.1 s lang ist und dessen Amplitude linear fällt 

# Ab hier nichts mehr ändern
MP3.AB1A1dPlay(A)
MP3.AB1Aufgabe1d(A)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1A1d.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>
# ┌ Warning: Bei t = 1 hat die Amplitude nicht den Wert 0!
# └ @ Main.MP3 D:\RWTH\CAMMP\CAMMPcloud\CAMMPDay_mp3\MP3_Blaetter\code\MP3Tests.jl:127

# %% [markdown]
# # Hörmodell
#
# Nachdem auf dem letzten Arbeitsblatt die Frage geklärt wurde, wie man die Frequenzen aus einem Audiosignal erhält, soll nun geklärt werden, welche Frequenzen aus dem Original Signal gestrichen werden können. Es erscheint logisch die Töne zu streichen, welche vom menschlichen Gehör nicht wahrgenommen werden können. Auf diesem Arbeitsblatt sollt ihr selber eure Hörschwelle testen und am Ende Kriterien angeben können, nach denen Töne aus einem Song herausgeﬁltert werden können.
#
# ##  Konﬂikt: Qualität vs. Quantität
#
# Fast immer, wenn die Forderung gestellt wird, Daten zu komprimieren, um mehr Datenmengen speichern zu können, ist damit ein Qualitätsverlust verbunden. Auch beim mp3 Verfahren war es die Aufgabe Speicherplatz z.B. von Musik einzusparen. Die Herausforderung war es, einen Song nur soweit zu komprimieren, dass er immer noch eine gute Qualität aufweist und man als Hörer nicht nur Rauschen wahrnimmt. Dazu wurde ein komplexes Hörmodell entwickelt, welches die Töne eines Songs, welche der Mensch gar nicht oder sehr gering wahrnehmen kann, aus einem Song raus streicht.
#
# ![Schwelle](../MP3_Bilder/schwelle.jpg)
#
# *Damit dieses Arbeitsblatt funktioniert, musst du als erstes den folgenden Code ausführen. Klicke dazu auf das Code Feld und drücke auf "Run" (oder drücke Shift + Enter).*

# %%
# Hier nichts ändern
include("./code/MP3Tests.jl")
# Out:
# WARNING: replacing module MP3.
# Main.MP3

# %% [markdown]
# ## Aufgabe 1 *a)* | Zu hohe und zu tiefe Teiltöne
#
# **Hinweis**: Achtet darauf, dass bei der Aufgabe die Lautstärke am Laptop nicht höher als bis zu Hälfte aufgedreht ist!
#
# Testet zunächst was die höchste Frequenz ist, die ihr gerade noch wahrnehmen könnt und ab der ihr nichts mehr hört. Gebt dazu Frequenzen für `f_h` ein. Eure Frequenz sollte nicht höher als 21000 sein!
#
# *Ersetzt im folgenden Code `f_h` mit der Frequenz, die ihr abspielen wollt. Klickt anschließend auf "Run".*

# %%
f_h = NaN; # Ersetzt NaN durch entsprechende Frequenzen
MP3.AB3A1aPlay(f_h);
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB3A1.wav.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ## Aufgabe 1 *b)*
#
# Testet nun welches die niedrigste Frequenz `f_t` ist, die ihr noch hören könnt. Dazu verfahrt ihr genau so wie in Teil *a)*.

# %%
f_t = NaN; # Ersetzt NaN durch entsprechende Frequenzen
MP3.AB3A1aPlay(f_t);
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB3A1.wav.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# Tragt eure Egebnisse nun hier ein:

# %%
# höchste Frequenz [Hz] = 
# tiefste Frequenz [Hz] =

# %% [markdown]
# ## Aufgabe 1 *c)*
#
# Führt nun folgenden Code aus, der euch einen Akkord vorspielt.

# %%
# Hier nichts ändern
MP3.AB3A1cPlay();
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB3A1c.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# Folgender Code erstellt euch ein Spektogram der einzelnen Frequenzen des Akkords. Was fällt euch auf?
#
# *Klickt "Run" um das Frequenzspektrum angezeigt zu bekommen.*

# %%
# Hier nichts ändern
MP3.AB3Aufgabe1c()

# %% [markdown]
# ## Aufgabe 2 | Ähnliche Teiltöne
#
# Wir werden nun ein weiteres akustisches Phänomen betrachten. Im folgenden Code sind einige Frequenzen vorgegeben hört euch zunächst den Dreiklang bestehend aus diesen an indem ihr den Code ausführt.

# %%
# Hier nichts ändern
f_1 = 150
f_2 = 430
f_3 = 1010
MP3.AB3A2aPlay(f_1, f_2, f_3);
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB2A31.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# Ersetzt im folgenden Code das `NaN` bei `f_4 = NaN` durch eine Frequenz, die nah an einer der anderen drei ist. Wenn ihr nun den Code ausführt wird der Ton und der Graph der Sinusschwingungen angezeigt.
#
# *Ersetzt `NaN` durch eine entsprechende Frequenz und klickt "Run"*

# %%
f_4 = 432 # Ersetze hier NaN durch eine Frequenz, die nah an einer der anderen ist
MP3.AB3A2bPlay(f_4);
MP3.AB3A2Aufgabe2b(f_4)

# %% [markdown]
# Im folgenden wird der Ton bestehen aus allen vier Frequenzen abgespielt und der Graph mit allen Sinusschwingungen angezeigt. Ihr könnt alle drei Tonschnipsel, den Dreiklang, den Vierkland und den einzelnen Ton, beliebig oft abspielen. Was fällt euch auf?

# %%
MP3.AB3A2cPlay(f_1, f_2, f_3, f_4);
MP3.AB3Aufgabe2c(f_1, f_2, f_3, f_4)
